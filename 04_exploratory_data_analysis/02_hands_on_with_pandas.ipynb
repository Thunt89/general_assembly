# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Hands on with Pandas
#
# ---

# %% [markdown]
# ### Using Pandas
#
# Pandas is frequently used in data science because it offers a large set of commonly used functions, is relatively fast, and has a large community. Because many data science libraries also use NumPy to manipulate data, you can easily transfer data between libraries (as we will often do in this class!).
#
# Pandas is a large library that typically takes a lot of practice to learn. It heavily overrides Python operators, resulting in odd-looking syntax. For example, given a `DataFrame` called `cars` which contains a column `mpg`, we might want to view all cars with mpg over 35. To do this, we might write: `cars[cars['mpg'] > 35]`. In standard Python, this would most likely give a syntax error.
#
# Pandas also highly favors certain patterns of use. For example, looping through a `DataFrame` row by row is highly discouraged. Instead, Pandas favors using **vectorized functions** that operate column by column. (This is because each column is stored separately as an `ndarray`, and NumPy is optimized for operating on `ndarray`s.)
#
# Do not be discouraged if Pandas feels overwhelming. Gradually, as you use it, you will become familiar with which methods to use and the "Pandas way" of thinking about and manipulating data.

# %%
# Load Pandas into Python
import pandas as pd

# %% [markdown]
# <a id="reading-files"></a>
# ### Reading Files, Selecting Columns, and Summarizing

# %%
users = pd.read_table('data/user.tbl', sep='|')

# %% [markdown]
# **Examine the users data.**

# %%
type(users)             # check its type
# Out:
# pandas.core.frame.DataFrame

# %%
users                   # Print the first 30 and last 30 rows.
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# 5          6   42      M      executive    98101
# 6          7   57      M  administrator    91344
# 7          8   36      M  administrator    05201
# 8          9   29      M        student    01002
# 9         10   53      M         lawyer    90703
# 10        11   39      F          other    30329
# 11        12   28      F          other    06405
# 12        13   47      M       educator    29206
# 13        14   45      M      scientist    55106
# 14        15   49      F       educator    97301
# 15        16   21      M  entertainment    10309
# 16        17   30      M     programmer    06355
# 17        18   35      F          other    37212
# 18        19   40      M      librarian    02138
# 19        20   42      F      homemaker    95660
# 20        21   26      M         writer    30068
# 21        22   25      M         writer    40206
# 22        23   30      F         artist    48197
# 23        24   21      F         artist    94533
# 24        25   39      M       engineer    55107
# 25        26   49      M       engineer    21044
# 26        27   40      F      librarian    30030
# 27        28   32      M         writer    55369
# 28        29   41      M     programmer    94043
# 29        30    7      M        student    55436
# ..       ...  ...    ...            ...      ...
# 913      914   44      F          other    08105
# 914      915   50      M  entertainment    60614
# 915      916   27      M       engineer    N2L5N
# 916      917   22      F        student    20006
# 917      918   40      M      scientist    70116
# 918      919   25      M          other    14216
# 919      920   30      F         artist    90008
# 920      921   20      F        student    98801
# 921      922   29      F  administrator    21114
# 922      923   21      M        student    E2E3R
# 923      924   29      M          other    11753
# 924      925   18      F       salesman    49036
# 925      926   49      M  entertainment    01701
# 926      927   23      M     programmer    55428
# 927      928   21      M        student    55408
# 928      929   44      M      scientist    53711
# 929      930   28      F      scientist    07310
# 930      931   60      M       educator    33556
# 931      932   58      M       educator    06437
# 932      933   28      M        student    48105
# 933      934   61      M       engineer    22902
# 934      935   42      M         doctor    66221
# 935      936   24      M          other    32789
# 936      937   48      M       educator    98072
# 937      938   38      F     technician    55038
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
users.head()            # Print the first five rows.
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
users.head(10)          # Print the first 10 rows.
# Out:
#    user_id  age gender     occupation zip_code
# 0        1   24      M     technician    85711
# 1        2   53      F          other    94043
# 2        3   23      M         writer    32067
# 3        4   24      M     technician    43537
# 4        5   33      F          other    15213
# 5        6   42      M      executive    98101
# 6        7   57      M  administrator    91344
# 7        8   36      M  administrator    05201
# 8        9   29      M        student    01002
# 9       10   53      M         lawyer    90703

# %%
users.tail()            # Print the last five rows.
# Out:
#      user_id  age gender     occupation zip_code
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
# The row index (aka "the row labels" — in this case integers)
users.index
# Out:
# RangeIndex(start=0, stop=943, step=1)

# %%
# Column names (which is "an index")
users.columns
# Out:
# Index(['user_id', 'age', 'gender', 'occupation', 'zip_code'], dtype='object')

# %%
# Datatypes of each column — each column is stored as an ndarray, which has a datatype
users.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
# Number of rows and columns
users.shape
# Out:
# (943, 5)

# %%
# All values as a NumPy array
users.values
# Out:
# array([[1, 24, 'M', 'technician', '85711'],
#        [2, 53, 'F', 'other', '94043'],
#        [3, 23, 'M', 'writer', '32067'],
#        ...,
#        [941, 20, 'M', 'student', '97229'],
#        [942, 48, 'F', 'librarian', '78209'],
#        [943, 22, 'M', 'student', '77841']], dtype=object)

# %%
# Concise summary (including memory usage) — useful to quickly see if nulls exist
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 943 entries, 0 to 942
# Data columns (total 5 columns):
# user_id       943 non-null int64
# age           943 non-null int64
# gender        943 non-null object
# occupation    943 non-null object
# zip_code      943 non-null object
# dtypes: int64(2), object(3)
# memory usage: 36.9+ KB

# %% [markdown]
# ** Select or index data.**<br>
# Pandas `DataFrame`s have structural similarities with Python-style lists and dictionaries.
# In the example below, we select a column of data using the name of the column in a similar manner to how we select a dictionary value with the dictionary key.

# %%
# Select a column
users['occupation']
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
# 5          executive
# 6      administrator
# 7      administrator
# 8            student
# 9             lawyer
# 10             other
# 11             other
# 12          educator
# 13         scientist
# 14          educator
# 15     entertainment
# 16        programmer
# 17             other
# 18         librarian
# 19         homemaker
# 20            writer
# 21            writer
# 22            artist
# 23            artist
# 24          engineer
# 25          engineer
# 26         librarian
# 27            writer
# 28        programmer
# 29           student
#            ...
# 913            other
# 914    entertainment
# 915         engineer
# 916          student
# 917        scientist
# 918            other
# 919           artist
# 920          student
# 921    administrator
# 922          student
# 923            other
# 924         salesman
# 925    entertainment
# 926       programmer
# 927          student
# 928        scientist
# 929        scientist
# 930         educator
# 931         educator
# 932          student
# 933         engineer
# 934           doctor
# 935            other
# 936         educator
# 937       technician
# 938          student
# 939    administrator
# 940          student
# 941        librarian
# 942          student
# Name: occupation, Length: 943, dtype: object

# %%
type(users['occupation'])
# Out:
# pandas.core.series.Series

# %%
# Select one column using the DataFrame attribute. (could be wrong if name is a python key word)
users.occupation

# While a useful shorthand, these attributes only exist
# if the column name has no punctuations or spaces.
# Out:
# 0         technician
# 1              other
# 2             writer
# 3         technician
# 4              other
# 5          executive
# 6      administrator
# 7      administrator
# 8            student
# 9             lawyer
# 10             other
# 11             other
# 12          educator
# 13         scientist
# 14          educator
# 15     entertainment
# 16        programmer
# 17             other
# 18         librarian
# 19         homemaker
# 20            writer
# 21            writer
# 22            artist
# 23            artist
# 24          engineer
# 25          engineer
# 26         librarian
# 27            writer
# 28        programmer
# 29           student
#            ...
# 913            other
# 914    entertainment
# 915         engineer
# 916          student
# 917        scientist
# 918            other
# 919           artist
# 920          student
# 921    administrator
# 922          student
# 923            other
# 924         salesman
# 925    entertainment
# 926       programmer
# 927          student
# 928        scientist
# 929        scientist
# 930         educator
# 931         educator
# 932          student
# 933         engineer
# 934           doctor
# 935            other
# 936         educator
# 937       technician
# 938          student
# 939    administrator
# 940          student
# 941        librarian
# 942          student
# Name: occupation, Length: 943, dtype: object

# %% [markdown]
# **Summarize (describe) the data.**<br>
# Pandas has a bunch of built-in methods to quickly summarize your data and provide you with a quick general understanding.

# %%
# Describe all numeric columns.
users.describe()
# Out:
#           user_id         age
# count  943.000000  943.000000
# mean   472.000000   34.051962
# std    272.364951   12.192740
# min      1.000000    7.000000
# 25%    236.500000   25.000000
# 50%    472.000000   31.000000
# 75%    707.500000   43.000000
# max    943.000000   73.000000

# %%
# Describe all columns, including non-numeric.
users.describe(include='all')
# Out:
#            user_id         age gender occupation zip_code
# count   943.000000  943.000000    943        943      943
# unique         NaN         NaN      2         21      795
# top            NaN         NaN      M    student    55414
# freq           NaN         NaN    670        196        9
# mean    472.000000   34.051962    NaN        NaN      NaN
# std     272.364951   12.192740    NaN        NaN      NaN
# min       1.000000    7.000000    NaN        NaN      NaN
# 25%     236.500000   25.000000    NaN        NaN      NaN
# 50%     472.000000   31.000000    NaN        NaN      NaN
# 75%     707.500000   43.000000    NaN        NaN      NaN
# max     943.000000   73.000000    NaN        NaN      NaN

# %%
# Describe a single column — recall that "users.occupation" refers to a Series.
users["occupation"].describe()
# Out:
# count         943
# unique         21
# top       student
# freq          196
# Name: occupation, dtype: object

# %%
# Calculate the mean of the ages.
users["age"].mean()
# Out:
# 34.05196182396607

# %% [markdown]
# **Count the number of occurrences of each value.**

# %%
users["occupation"].value_counts()     # Most useful for categorical variables
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# salesman          12
# lawyer            12
# none               9
# doctor             7
# homemaker          7
# Name: occupation, dtype: int64

# %%
# Can also be used with numeric variables
#   Try .sort_index() to sort by indices or .sort_values() to sort by counts.
users["age"].value_counts()
# Out:
# 30    39
# 25    38
# 22    37
# 28    36
# 27    35
# 26    34
# 24    33
# 29    32
# 20    32
# 32    28
# 23    28
# 35    27
# 21    27
# 33    26
# 31    25
# 19    23
# 44    23
# 39    22
# 40    21
# 36    21
# 42    21
# 51    20
# 50    20
# 48    20
# 49    19
# 37    19
# 18    18
# 34    17
# 38    17
# 45    15
#       ..
# 47    14
# 43    13
# 46    12
# 53    12
# 55    11
# 41    10
# 57     9
# 60     9
# 52     6
# 56     6
# 15     6
# 13     5
# 16     5
# 54     4
# 63     3
# 14     3
# 65     3
# 70     3
# 61     3
# 59     3
# 58     3
# 64     2
# 68     2
# 69     2
# 62     2
# 11     1
# 10     1
# 73     1
# 66     1
# 7      1
# Name: age, Length: 61, dtype: int64

# %%
# You can also do it the "long way"
users.groupby("occupation")["user_id"].count()
# Out:
# occupation
# administrator     79
# artist            28
# doctor             7
# educator          95
# engineer          67
# entertainment     18
# executive         32
# healthcare        16
# homemaker          7
# lawyer            12
# librarian         51
# marketing         26
# none               9
# other            105
# programmer        66
# retired           14
# salesman          12
# scientist         31
# student          196
# technician        27
# writer            45
# Name: user_id, dtype: int64

# %% [markdown]
# <a id="exercise-one"></a>
# ### Exercise 1

# %%
# Read drinks.csv into a DataFrame called "drinks".
drinks = pd.read_csv('data/drinks.csv')

# %%
# Print the head and the tail.
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.tail()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 188  Venezuela            333              100              3
# 189    Vietnam            111                2              1
# 190      Yemen              6                0              0
# 191     Zambia             32               19              4
# 192   Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol continent
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF

# %%
# Examine the default index, datatypes, and shape.
drinks.index, drinks.shape
# Out:
# (RangeIndex(start=0, stop=193, step=1), (193, 6))

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
# Print the beer_servings Series.
drinks['beer_servings']
# Out:
# 0        0
# 1       89
# 2       25
# 3      245
# 4      217
# 5      102
# 6      193
# 7       21
# 8      261
# 9      279
# 10      21
# 11     122
# 12      42
# 13       0
# 14     143
# 15     142
# 16     295
# 17     263
# 18      34
# 19      23
# 20     167
# 21      76
# 22     173
# 23     245
# 24      31
# 25     231
# 26      25
# 27      88
# 28      37
# 29     144
#       ...
# 163    128
# 164     90
# 165    152
# 166    185
# 167      5
# 168      2
# 169     99
# 170    106
# 171      1
# 172     36
# 173     36
# 174    197
# 175     51
# 176     51
# 177     19
# 178      6
# 179     45
# 180    206
# 181     16
# 182    219
# 183     36
# 184    249
# 185    115
# 186     25
# 187     21
# 188    333
# 189    111
# 190      6
# 191     32
# 192     64
# Name: beer_servings, Length: 193, dtype: int64

# %%
# Calculate the average beer_servings for the entire data set.
drinks['beer_servings'].mean()
# Out:
# 106.16062176165804

# %%
# Count the number of occurrences of each "continent" value and see if it looks correct.
drinks.groupby("continent")['continent'].count()
# Out:
# continent
# AF    53
# AS    44
# EU    45
# OC    16
# SA    12
# Name: continent, dtype: int64

# %%
# Or more simply
drinks['continent'].value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: continent, dtype: int64

# %% [markdown]
# <a id="filtering-and-sorting"></a>
# ### Filtering and Sorting
# - **Objective:** Filter and sort data using Pandas.
#
# We can use simple operator comparisons on columns to extract relevant or drop irrelevant information.

# %% [markdown]
# **Logical filtering: Only show users with age < 20.**

# %%
# Create a Series of Booleans…
# In Pandas, this comparison is performed element-wise on each row of data.
young_bool = users["age"] < 20
young_bool
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29      True
#        ...
# 913    False
# 914    False
# 915    False
# 916    False
# 917    False
# 918    False
# 919    False
# 920    False
# 921    False
# 922    False
# 923    False
# 924     True
# 925    False
# 926    False
# 927    False
# 928    False
# 929    False
# 930    False
# 931    False
# 932    False
# 933    False
# 934    False
# 935    False
# 936    False
# 937    False
# 938    False
# 939    False
# 940    False
# 941    False
# 942    False
# Name: age, Length: 943, dtype: bool

# %%
# …and use that Series to filter rows.
# In Pandas, indexing a DataFrame by a Series of Booleans only selects rows that are True in the Boolean.
users[young_bool]
# Out:
#      user_id  age gender     occupation zip_code  is_under_20
# 29        30    7      M        student    55436         True
# 35        36   19      F        student    93117         True
# 51        52   18      F        student    55105         True
# 56        57   16      M           none    84010         True
# 66        67   17      M        student    60402         True
# 67        68   19      M        student    22904         True
# 100      101   15      M        student    05146         True
# 109      110   19      M        student    77840         True
# 141      142   13      M          other    48118         True
# 178      179   15      M  entertainment    20755         True
# 205      206   14      F        student    53115         True
# 220      221   19      M        student    20685         True
# 222      223   19      F        student    47906         True
# 245      246   19      M        student    28734         True
# 256      257   17      M        student    77005         True
# 257      258   19      F        student    77801         True
# 261      262   19      F        student    78264         True
# 269      270   18      F        student    63119         True
# 280      281   15      F        student    06059         True
# 288      289   11      M           none    94619         True
# 290      291   19      M        student    44106         True
# 302      303   19      M        student    14853         True
# 319      320   19      M        student    24060         True
# 340      341   17      F        student    44405         True
# 346      347   18      M        student    90210         True
# 366      367   17      M        student    37411         True
# 367      368   18      M        student    92113         True
# 374      375   17      M  entertainment    37777         True
# 392      393   19      M        student    83686         True
# 396      397   17      M        student    27514         True
# ..       ...  ...    ...            ...      ...          ...
# 600      601   19      F         artist    99687         True
# 608      609   13      F        student    55106         True
# 617      618   15      F        student    44212         True
# 618      619   17      M        student    44134         True
# 619      620   18      F         writer    81648         True
# 620      621   17      M        student    60402         True
# 623      624   19      M        student    30067         True
# 627      628   13      M           none    94306         True
# 630      631   18      F        student    38866         True
# 631      632   18      M        student    55454         True
# 641      642   18      F        student    95521         True
# 645      646   17      F        student    51250         True
# 673      674   13      F        student    55337         True
# 699      700   17      M        student    76309         True
# 709      710   19      M        student    92020         True
# 728      729   19      M        student    56567         True
# 746      747   19      M          other    93612         True
# 760      761   17      M        student    97302         True
# 786      787   18      F        student    98620         True
# 812      813   14      F        student    02136         True
# 816      817   19      M        student    60152         True
# 848      849   15      F        student    25652         True
# 850      851   18      M          other    29646         True
# 858      859   18      F          other    06492         True
# 862      863   17      M        student    60089         True
# 871      872   19      F        student    74078         True
# 879      880   13      M        student    83702         True
# 886      887   14      F        student    27249         True
# 903      904   17      F        student    61073         True
# 924      925   18      F       salesman    49036         True
#
# [77 rows x 6 columns]

# %%
# Or, combine into a single step.
users[users["age"] < 20]
# Out:
#      user_id  age gender     occupation zip_code  is_under_20
# 29        30    7      M        student    55436         True
# 35        36   19      F        student    93117         True
# 51        52   18      F        student    55105         True
# 56        57   16      M           none    84010         True
# 66        67   17      M        student    60402         True
# 67        68   19      M        student    22904         True
# 100      101   15      M        student    05146         True
# 109      110   19      M        student    77840         True
# 141      142   13      M          other    48118         True
# 178      179   15      M  entertainment    20755         True
# 205      206   14      F        student    53115         True
# 220      221   19      M        student    20685         True
# 222      223   19      F        student    47906         True
# 245      246   19      M        student    28734         True
# 256      257   17      M        student    77005         True
# 257      258   19      F        student    77801         True
# 261      262   19      F        student    78264         True
# 269      270   18      F        student    63119         True
# 280      281   15      F        student    06059         True
# 288      289   11      M           none    94619         True
# 290      291   19      M        student    44106         True
# 302      303   19      M        student    14853         True
# 319      320   19      M        student    24060         True
# 340      341   17      F        student    44405         True
# 346      347   18      M        student    90210         True
# 366      367   17      M        student    37411         True
# 367      368   18      M        student    92113         True
# 374      375   17      M  entertainment    37777         True
# 392      393   19      M        student    83686         True
# 396      397   17      M        student    27514         True
# ..       ...  ...    ...            ...      ...          ...
# 600      601   19      F         artist    99687         True
# 608      609   13      F        student    55106         True
# 617      618   15      F        student    44212         True
# 618      619   17      M        student    44134         True
# 619      620   18      F         writer    81648         True
# 620      621   17      M        student    60402         True
# 623      624   19      M        student    30067         True
# 627      628   13      M           none    94306         True
# 630      631   18      F        student    38866         True
# 631      632   18      M        student    55454         True
# 641      642   18      F        student    95521         True
# 645      646   17      F        student    51250         True
# 673      674   13      F        student    55337         True
# 699      700   17      M        student    76309         True
# 709      710   19      M        student    92020         True
# 728      729   19      M        student    56567         True
# 746      747   19      M          other    93612         True
# 760      761   17      M        student    97302         True
# 786      787   18      F        student    98620         True
# 812      813   14      F        student    02136         True
# 816      817   19      M        student    60152         True
# 848      849   15      F        student    25652         True
# 850      851   18      M          other    29646         True
# 858      859   18      F          other    06492         True
# 862      863   17      M        student    60089         True
# 871      872   19      F        student    74078         True
# 879      880   13      M        student    83702         True
# 886      887   14      F        student    27249         True
# 903      904   17      F        student    61073         True
# 924      925   18      F       salesman    49036         True
#
# [77 rows x 6 columns]

# %%
# Important: This creates a view of the original DataFrame, not a new DataFrame.
# If you alter this view (e.g., by storing it in a variable and altering that)
# You will alter only the slice of the DataFrame and not the actual DataFrame itself
# Here, notice that Pandas gives you a SettingWithCopyWarning to alert you of this.

# It is best practice to use .loc and .iloc instead of the syntax below

users_under20 = users[users["age"] < 20].copy()   # To resolve this warning, copy the `DataFrame` using `.copy()`.
users_under20['is_under_20'] = True # This adds a new column

# %%
users.head()
# Out:
#    user_id  age gender  occupation zip_code  is_under_20
# 0        1   24      M  technician    85711        False
# 1        2   53      F       other    94043        False
# 2        3   23      M      writer    32067        False
# 3        4   24      M  technician    43537        False
# 4        5   33      F       other    15213        False

# %%
users_under20.head()
# Out:
#     user_id  age gender occupation zip_code  is_under_20
# 29       30    7      M    student    55436         True
# 35       36   19      F    student    93117         True
# 51       52   18      F    student    55105         True
# 56       57   16      M       none    84010         True
# 66       67   17      M    student    60402         True

# %% [markdown]
# To create the is_under_20 column in the original DataFrame we could use `.loc`
#
# The syntax is:
#
# `my_dataframe.loc[<filter_condition>, <column>] = <new_value>`

# %%
users.loc[users["age"] < 20, "is_under_20"] = True
users.head()
# Out:
#    user_id  age gender  occupation zip_code  is_under_20
# 0        1   24      M  technician    85711        False
# 1        2   53      F       other    94043        False
# 2        3   23      M      writer    32067        False
# 3        4   24      M  technician    43537        False
# 4        5   33      F       other    15213        False

# %%
users.loc[users["age"] >= 20, "is_under_20"] = False
users.head()
# Out:
#    user_id  age gender  occupation zip_code  is_under_20
# 0        1   24      M  technician    85711        False
# 1        2   53      F       other    94043        False
# 2        3   23      M      writer    32067        False
# 3        4   24      M  technician    43537        False
# 4        5   33      F       other    15213        False

# %% [markdown]
# `.loc` is also useful if you want to filter **both** rows and columns at the same time

# %%
# Select two columns from the filtered results.
users.loc[users["is_under_20"], ["occupation", "age"]]
# Out:
#         occupation  age
# 29         student    7
# 35         student   19
# 51         student   18
# 56            none   16
# 66         student   17
# 67         student   19
# 100        student   15
# 109        student   19
# 141          other   13
# 178  entertainment   15
# 205        student   14
# 220        student   19
# 222        student   19
# 245        student   19
# 256        student   17
# 257        student   19
# 261        student   19
# 269        student   18
# 280        student   15
# 288           none   11
# 290        student   19
# 302        student   19
# 319        student   19
# 340        student   17
# 346        student   18
# 366        student   17
# 367        student   18
# 374  entertainment   17
# 392        student   19
# 396        student   17
# ..             ...  ...
# 600         artist   19
# 608        student   13
# 617        student   15
# 618        student   17
# 619         writer   18
# 620        student   17
# 623        student   19
# 627           none   13
# 630        student   18
# 631        student   18
# 641        student   18
# 645        student   17
# 673        student   13
# 699        student   17
# 709        student   19
# 728        student   19
# 746          other   19
# 760        student   17
# 786        student   18
# 812        student   14
# 816        student   19
# 848        student   15
# 850          other   18
# 858          other   18
# 862        student   17
# 871        student   19
# 879        student   13
# 886        student   14
# 903        student   17
# 924       salesman   18
#
# [77 rows x 2 columns]

# %%
# Or you can just specify row numbers
users.loc[0:100, ["occupation", "age"]]
# Out:
#         occupation  age
# 0       technician   24
# 1            other   53
# 2           writer   23
# 3       technician   24
# 4            other   33
# 5        executive   42
# 6    administrator   57
# 7    administrator   36
# 8          student   29
# 9           lawyer   53
# 10           other   39
# 11           other   28
# 12        educator   47
# 13       scientist   45
# 14        educator   49
# 15   entertainment   21
# 16      programmer   30
# 17           other   35
# 18       librarian   40
# 19       homemaker   42
# 20          writer   26
# 21          writer   25
# 22          artist   30
# 23          artist   21
# 24        engineer   39
# 25        engineer   49
# 26       librarian   40
# 27          writer   32
# 28      programmer   41
# 29         student    7
# ..             ...  ...
# 71   administrator   48
# 72         student   24
# 73       scientist   39
# 74   entertainment   24
# 75         student   20
# 76      technician   30
# 77   administrator   26
# 78   administrator   39
# 79   administrator   34
# 80         student   21
# 81      programmer   50
# 82           other   40
# 83       executive   32
# 84        educator   51
# 85   administrator   26
# 86   administrator   47
# 87       librarian   49
# 88   administrator   43
# 89        educator   60
# 90       marketing   55
# 91   entertainment   32
# 92       executive   48
# 93         student   26
# 94   administrator   31
# 95          artist   25
# 96          artist   43
# 97       executive   49
# 98         student   20
# 99       executive   36
# 100        student   15
#
# [101 rows x 2 columns]

# %% [markdown]
# **Logical filtering with multiple conditions**

# %%
# Ampersand for `AND` condition. (This is a "bitwise" `AND`.)
# Important: You MUST put parentheses around each expression because `&` has a higher precedence than `<`.
users[(users["is_under_20"]) & (users["gender"] == 'M')]
# Out:
#      user_id  age gender     occupation zip_code  is_under_20
# 29        30    7      M        student    55436         True
# 56        57   16      M           none    84010         True
# 66        67   17      M        student    60402         True
# 67        68   19      M        student    22904         True
# 100      101   15      M        student    05146         True
# 109      110   19      M        student    77840         True
# 141      142   13      M          other    48118         True
# 178      179   15      M  entertainment    20755         True
# 220      221   19      M        student    20685         True
# 245      246   19      M        student    28734         True
# 256      257   17      M        student    77005         True
# 288      289   11      M           none    94619         True
# 290      291   19      M        student    44106         True
# 302      303   19      M        student    14853         True
# 319      320   19      M        student    24060         True
# 346      347   18      M        student    90210         True
# 366      367   17      M        student    37411         True
# 367      368   18      M        student    92113         True
# 374      375   17      M  entertainment    37777         True
# 392      393   19      M        student    83686         True
# 396      397   17      M        student    27514         True
# 424      425   19      M        student    58644         True
# 450      451   16      M        student    48446         True
# 452      453   18      M        student    06333         True
# 460      461   15      M        student    98102         True
# 470      471   10      M        student    77459         True
# 520      521   19      M        student    02146         True
# 527      528   18      M        student    55104         True
# 579      580   16      M        student    17961         True
# 581      582   17      M        student    93003         True
# 591      592   18      M        student    97520         True
# 618      619   17      M        student    44134         True
# 620      621   17      M        student    60402         True
# 623      624   19      M        student    30067         True
# 627      628   13      M           none    94306         True
# 631      632   18      M        student    55454         True
# 699      700   17      M        student    76309         True
# 709      710   19      M        student    92020         True
# 728      729   19      M        student    56567         True
# 746      747   19      M          other    93612         True
# 760      761   17      M        student    97302         True
# 816      817   19      M        student    60152         True
# 850      851   18      M          other    29646         True
# 862      863   17      M        student    60089         True
# 879      880   13      M        student    83702         True

# %%
users[(users["age"] <20) & (users["gender"] == 'M')] # The same thing, but with age column rather than is_under_20 column
# Out:
#      user_id  age gender     occupation zip_code  is_under_20
# 29        30    7      M        student    55436         True
# 56        57   16      M           none    84010         True
# 66        67   17      M        student    60402         True
# 67        68   19      M        student    22904         True
# 100      101   15      M        student    05146         True
# 109      110   19      M        student    77840         True
# 141      142   13      M          other    48118         True
# 178      179   15      M  entertainment    20755         True
# 220      221   19      M        student    20685         True
# 245      246   19      M        student    28734         True
# 256      257   17      M        student    77005         True
# 288      289   11      M           none    94619         True
# 290      291   19      M        student    44106         True
# 302      303   19      M        student    14853         True
# 319      320   19      M        student    24060         True
# 346      347   18      M        student    90210         True
# 366      367   17      M        student    37411         True
# 367      368   18      M        student    92113         True
# 374      375   17      M  entertainment    37777         True
# 392      393   19      M        student    83686         True
# 396      397   17      M        student    27514         True
# 424      425   19      M        student    58644         True
# 450      451   16      M        student    48446         True
# 452      453   18      M        student    06333         True
# 460      461   15      M        student    98102         True
# 470      471   10      M        student    77459         True
# 520      521   19      M        student    02146         True
# 527      528   18      M        student    55104         True
# 579      580   16      M        student    17961         True
# 581      582   17      M        student    93003         True
# 591      592   18      M        student    97520         True
# 618      619   17      M        student    44134         True
# 620      621   17      M        student    60402         True
# 623      624   19      M        student    30067         True
# 627      628   13      M           none    94306         True
# 631      632   18      M        student    55454         True
# 699      700   17      M        student    76309         True
# 709      710   19      M        student    92020         True
# 728      729   19      M        student    56567         True
# 746      747   19      M          other    93612         True
# 760      761   17      M        student    97302         True
# 816      817   19      M        student    60152         True
# 850      851   18      M          other    29646         True
# 862      863   17      M        student    60089         True
# 879      880   13      M        student    83702         True

# %%
# Pipe for `OR` condition. (This is a "bitwise" `OR`.)
# Important: You MUST put parentheses around each expression because `|` has a higher precedence than `<`.
users[(users["is_under_20"]) | (users["age"] > 60)]
# Out:
#      user_id  age gender     occupation zip_code  is_under_20
# 29        30    7      M        student    55436         True
# 35        36   19      F        student    93117         True
# 51        52   18      F        student    55105         True
# 56        57   16      M           none    84010         True
# 66        67   17      M        student    60402         True
# 67        68   19      M        student    22904         True
# 100      101   15      M        student    05146         True
# 105      106   61      M        retired    55125        False
# 109      110   19      M        student    77840         True
# 141      142   13      M          other    48118         True
# 178      179   15      M  entertainment    20755         True
# 205      206   14      F        student    53115         True
# 210      211   66      M       salesman    32605        False
# 220      221   19      M        student    20685         True
# 222      223   19      F        student    47906         True
# 245      246   19      M        student    28734         True
# 256      257   17      M        student    77005         True
# 257      258   19      F        student    77801         True
# 261      262   19      F        student    78264         True
# 265      266   62      F  administrator    78756        False
# 269      270   18      F        student    63119         True
# 280      281   15      F        student    06059         True
# 288      289   11      M           none    94619         True
# 290      291   19      M        student    44106         True
# 302      303   19      M        student    14853         True
# 317      318   65      M        retired    06518        False
# 319      320   19      M        student    24060         True
# 340      341   17      F        student    44405         True
# 346      347   18      M        student    90210         True
# 348      349   68      M        retired    61455        False
# ..       ...  ...    ...            ...      ...          ...
# 630      631   18      F        student    38866         True
# 631      632   18      M        student    55454         True
# 641      642   18      F        student    95521         True
# 645      646   17      F        student    51250         True
# 650      651   65      M        retired    02903        False
# 673      674   13      F        student    55337         True
# 699      700   17      M        student    76309         True
# 709      710   19      M        student    92020         True
# 728      729   19      M        student    56567         True
# 746      747   19      M          other    93612         True
# 760      761   17      M        student    97302         True
# 766      767   70      M       engineer    00000        False
# 776      777   63      M     programmer    01810        False
# 786      787   18      F        student    98620         True
# 802      803   70      M  administrator    78212        False
# 812      813   14      F        student    02136         True
# 816      817   19      M        student    60152         True
# 844      845   64      M         doctor    97405        False
# 848      849   15      F        student    25652         True
# 850      851   18      M          other    29646         True
# 857      858   63      M       educator    09645        False
# 858      859   18      F          other    06492         True
# 859      860   70      F        retired    48322        False
# 862      863   17      M        student    60089         True
# 871      872   19      F        student    74078         True
# 879      880   13      M        student    83702         True
# 886      887   14      F        student    27249         True
# 903      904   17      F        student    61073         True
# 924      925   18      F       salesman    49036         True
# 933      934   61      M       engineer    22902        False
#
# [99 rows x 6 columns]

# %%
# Preferred alternative to multiple `OR` conditions
users[users["occupation"].isin(['doctor', 'lawyer'])]
# Out:
#      user_id  age gender occupation zip_code  is_under_20
# 9         10   53      M     lawyer    90703        False
# 124      125   30      M     lawyer    22202        False
# 125      126   28      F     lawyer    20015        False
# 137      138   46      M     doctor    53211        False
# 160      161   50      M     lawyer    55104        False
# 204      205   47      M     lawyer    06371        False
# 250      251   28      M     doctor    85032        False
# 298      299   29      M     doctor    63108        False
# 338      339   35      M     lawyer    37901        False
# 364      365   29      M     lawyer    20009        False
# 418      419   37      M     lawyer    43215        False
# 426      427   51      M     doctor    85258        False
# 443      444   51      F     lawyer    53202        False
# 588      589   21      M     lawyer    90034        False
# 679      680   33      M     lawyer    90405        False
# 840      841   45      M     doctor    47401        False
# 844      845   64      M     doctor    97405        False
# 845      846   27      M     lawyer    47130        False
# 934      935   42      M     doctor    66221        False

# %% [markdown]
# **Sorting**

# %%
# Sort a Series.
users["age"].sort_values()
# Out:
# 29      7
# 470    10
# 288    11
# 879    13
# 608    13
# 141    13
# 673    13
# 627    13
# 812    14
# 205    14
# 886    14
# 848    15
# 280    15
# 460    15
# 617    15
# 178    15
# 100    15
# 56     16
# 579    16
# 549    16
# 450    16
# 433    16
# 620    17
# 618    17
# 760    17
# 374    17
# 903    17
# 645    17
# 581    17
# 256    17
#        ..
# 89     60
# 307    60
# 930    60
# 751    60
# 468    60
# 463    60
# 233    60
# 693    60
# 933    61
# 350    61
# 105    61
# 519    62
# 265    62
# 857    63
# 776    63
# 363    63
# 844    64
# 422    64
# 317    65
# 650    65
# 563    65
# 210    66
# 348    68
# 572    68
# 558    69
# 584    69
# 766    70
# 802    70
# 859    70
# 480    73
# Name: age, Length: 943, dtype: int64

# %%
# Sort a DataFrame by a single column.
users.sort_values('age')
# Out:
#      user_id  age gender     occupation zip_code  is_under_20
# 29        30    7      M        student    55436         True
# 470      471   10      M        student    77459         True
# 288      289   11      M           none    94619         True
# 879      880   13      M        student    83702         True
# 608      609   13      F        student    55106         True
# 141      142   13      M          other    48118         True
# 673      674   13      F        student    55337         True
# 627      628   13      M           none    94306         True
# 812      813   14      F        student    02136         True
# 205      206   14      F        student    53115         True
# 886      887   14      F        student    27249         True
# 848      849   15      F        student    25652         True
# 280      281   15      F        student    06059         True
# 460      461   15      M        student    98102         True
# 617      618   15      F        student    44212         True
# 178      179   15      M  entertainment    20755         True
# 100      101   15      M        student    05146         True
# 56        57   16      M           none    84010         True
# 579      580   16      M        student    17961         True
# 549      550   16      F        student    95453         True
# 450      451   16      M        student    48446         True
# 433      434   16      F        student    49705         True
# 620      621   17      M        student    60402         True
# 618      619   17      M        student    44134         True
# 760      761   17      M        student    97302         True
# 374      375   17      M  entertainment    37777         True
# 903      904   17      F        student    61073         True
# 645      646   17      F        student    51250         True
# 581      582   17      M        student    93003         True
# 256      257   17      M        student    77005         True
# ..       ...  ...    ...            ...      ...          ...
# 89        90   60      M       educator    78155        False
# 307      308   60      M        retired    95076        False
# 930      931   60      M       educator    33556        False
# 751      752   60      M        retired    21201        False
# 468      469   60      M       educator    78628        False
# 463      464   60      M         writer    94583        False
# 233      234   60      M        retired    94702        False
# 693      694   60      M     programmer    06365        False
# 933      934   61      M       engineer    22902        False
# 350      351   61      M       educator    49938        False
# 105      106   61      M        retired    55125        False
# 519      520   62      M     healthcare    12603        False
# 265      266   62      F  administrator    78756        False
# 857      858   63      M       educator    09645        False
# 776      777   63      M     programmer    01810        False
# 363      364   63      M       engineer    01810        False
# 844      845   64      M         doctor    97405        False
# 422      423   64      M          other    91606        False
# 317      318   65      M        retired    06518        False
# 650      651   65      M        retired    02903        False
# 563      564   65      M        retired    94591        False
# 210      211   66      M       salesman    32605        False
# 348      349   68      M        retired    61455        False
# 572      573   68      M        retired    48911        False
# 558      559   69      M      executive    10022        False
# 584      585   69      M      librarian    98501        False
# 766      767   70      M       engineer    00000        False
# 802      803   70      M  administrator    78212        False
# 859      860   70      F        retired    48322        False
# 480      481   73      M        retired    37771        False
#
# [943 rows x 6 columns]

# %%
# Use descending order instead.
users.sort_values('age', ascending=False)
# Out:
#      user_id  age gender     occupation zip_code  is_under_20
# 480      481   73      M        retired    37771        False
# 802      803   70      M  administrator    78212        False
# 766      767   70      M       engineer    00000        False
# 859      860   70      F        retired    48322        False
# 584      585   69      M      librarian    98501        False
# 558      559   69      M      executive    10022        False
# 348      349   68      M        retired    61455        False
# 572      573   68      M        retired    48911        False
# 210      211   66      M       salesman    32605        False
# 650      651   65      M        retired    02903        False
# 563      564   65      M        retired    94591        False
# 317      318   65      M        retired    06518        False
# 844      845   64      M         doctor    97405        False
# 422      423   64      M          other    91606        False
# 857      858   63      M       educator    09645        False
# 363      364   63      M       engineer    01810        False
# 776      777   63      M     programmer    01810        False
# 265      266   62      F  administrator    78756        False
# 519      520   62      M     healthcare    12603        False
# 933      934   61      M       engineer    22902        False
# 350      351   61      M       educator    49938        False
# 105      106   61      M        retired    55125        False
# 463      464   60      M         writer    94583        False
# 468      469   60      M       educator    78628        False
# 233      234   60      M        retired    94702        False
# 899      900   60      M        retired    18505        False
# 307      308   60      M        retired    95076        False
# 930      931   60      M       educator    33556        False
# 693      694   60      M     programmer    06365        False
# 751      752   60      M        retired    21201        False
# ..       ...  ...    ...            ...      ...          ...
# 699      700   17      M        student    76309         True
# 645      646   17      F        student    51250         True
# 862      863   17      M        student    60089         True
# 374      375   17      M  entertainment    37777         True
# 760      761   17      M        student    97302         True
# 620      621   17      M        student    60402         True
# 256      257   17      M        student    77005         True
# 903      904   17      F        student    61073         True
# 433      434   16      F        student    49705         True
# 450      451   16      M        student    48446         True
# 549      550   16      F        student    95453         True
# 56        57   16      M           none    84010         True
# 579      580   16      M        student    17961         True
# 178      179   15      M  entertainment    20755         True
# 460      461   15      M        student    98102         True
# 617      618   15      F        student    44212         True
# 848      849   15      F        student    25652         True
# 280      281   15      F        student    06059         True
# 100      101   15      M        student    05146         True
# 812      813   14      F        student    02136         True
# 886      887   14      F        student    27249         True
# 205      206   14      F        student    53115         True
# 627      628   13      M           none    94306         True
# 673      674   13      F        student    55337         True
# 141      142   13      M          other    48118         True
# 879      880   13      M        student    83702         True
# 608      609   13      F        student    55106         True
# 288      289   11      M           none    94619         True
# 470      471   10      M        student    77459         True
# 29        30    7      M        student    55436         True
#
# [943 rows x 6 columns]

# %%
# Sort by multiple columns.
users.sort_values(['occupation', 'age'])
# Out:
#      user_id  age gender     occupation zip_code  is_under_20
# 117      118   21      M  administrator    90210        False
# 179      180   22      F  administrator    60202        False
# 281      282   22      M  administrator    20057        False
# 316      317   22      M  administrator    13210        False
# 438      439   23      F  administrator    20817        False
# 508      509   23      M  administrator    10011        False
# 393      394   25      M  administrator    96819        False
# 664      665   25      M  administrator    55412        False
# 725      726   25      F  administrator    80538        False
# 77        78   26      M  administrator    61801        False
# 85        86   26      M  administrator    46005        False
# 61        62   27      F  administrator    97214        False
# 524      525   27      F  administrator    19711        False
# 260      261   28      M  administrator    85202        False
# 499      500   28      M  administrator    94305        False
# 747      748   28      M  administrator    94720        False
# 749      750   28      M  administrator    32303        False
# 767      768   29      M  administrator    12866        False
# 921      922   29      F  administrator    21114        False
# 41        42   30      M  administrator    17870        False
# 173      174   30      F  administrator    52302        False
# 189      190   30      M  administrator    95938        False
# 435      436   30      F  administrator    17345        False
# 446      447   30      M  administrator    55113        False
# 94        95   31      M  administrator    10707        False
# 577      578   31      M  administrator    M7A1A        False
# 761      762   32      M  administrator    95050        False
# 939      940   32      M  administrator    02215        False
# 190      191   33      M  administrator    95161        False
# 399      400   33      F  administrator    78213        False
# ..       ...  ...    ...            ...      ...          ...
# 667      668   29      F         writer    10016        False
# 198      199   30      M         writer    17604        False
# 556      557   30      F         writer    11217        False
# 27        28   32      M         writer    55369        False
# 121      122   32      F         writer    22206        False
# 795      796   32      F         writer    33755        False
# 832      833   34      M         writer    90019        False
# 263      264   36      F         writer    90064        False
# 384      385   36      M         writer    10003        False
# 910      911   37      F         writer    53210        False
# 503      504   40      F         writer    92115        False
# 797      798   40      F         writer    64131        False
# 841      842   40      M         writer    93055        False
# 389      390   42      F         writer    85016        False
# 744      745   42      M         writer    55113        False
# 490      491   43      F         writer    53711        False
# 235      236   44      F         writer    53214        False
# 388      389   44      F         writer    83702        False
# 735      736   48      F         writer    94618        False
# 828      829   48      M         writer    80209        False
# 195      196   49      M         writer    55105        False
# 517      518   49      F         writer    99709        False
# 852      853   49      M         writer    40515        False
# 502      503   50      F         writer    27514        False
# 771      772   50      M         writer    27105        False
# 547      548   51      M         writer    95468        False
# 369      370   52      M         writer    08534        False
# 391      392   52      M         writer    59801        False
# 557      558   56      F         writer    63132        False
# 463      464   60      M         writer    94583        False
#
# [943 rows x 6 columns]

# %% [markdown]
# <a id="exercise-two"></a>
# ### Exercise 2
# Use the `drinks.csv` or `drinks` `DataFrame` from earlier to complete the following.

# %%
# Filter DataFrame to only include European countries.
drinks[drinks["continent"]== 'EU']
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 1               Albania             89              132             54
# 3               Andorra            245              138            312
# 7               Armenia             21              179             11
# 9               Austria            279               75            191
# 10           Azerbaijan             21               46              5
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 21   Bosnia-Herzegovina             76              173              8
# 25             Bulgaria            231              252             94
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# 48              Denmark            224               81            278
# 57              Estonia            224              194             59
# 60              Finland            263              133             97
# 61               France            127              151            370
# 64              Georgia             52              100            149
# 65              Germany            346              117            175
# 67               Greece            133              112            218
# 75              Hungary            234              215            185
# 76              Iceland            233               61             78
# 81              Ireland            313              118            165
# 83                Italy             85               42            237
# 93               Latvia            281              216             62
# 98            Lithuania            343              244             56
# 99           Luxembourg            236              133            271
# 105               Malta            149              100            120
# 111              Monaco              0                0              0
# 113          Montenegro             31              114            128
# 120         Netherlands            251               88            190
# 126              Norway            169               71            129
# 135              Poland            343              215             56
# 136            Portugal            194               67            339
# 139             Moldova            109              226             18
# 140             Romania            297              122            167
# 147          San Marino              0                0              0
# 151              Serbia            283              131            127
# 155            Slovakia            196              293            116
# 156            Slovenia            270               51            276
# 160               Spain            284              157            112
# 165              Sweden            152               60            186
# 166         Switzerland            185              100            280
# 170           Macedonia            106               27             86
# 180             Ukraine            206              237             45
# 182      United Kingdom            219              126            195
#
#      total_litres_of_pure_alcohol continent
# 1                             4.9        EU
# 3                            12.4        EU
# 7                             3.8        EU
# 9                             9.7        EU
# 10                            1.3        EU
# 15                           14.4        EU
# 16                           10.5        EU
# 21                            4.6        EU
# 25                           10.3        EU
# 42                           10.2        EU
# 44                            8.2        EU
# 45                           11.8        EU
# 48                           10.4        EU
# 57                            9.5        EU
# 60                           10.0        EU
# 61                           11.8        EU
# 64                            5.4        EU
# 65                           11.3        EU
# 67                            8.3        EU
# 75                           11.3        EU
# 76                            6.6        EU
# 81                           11.4        EU
# 83                            6.5        EU
# 93                           10.5        EU
# 98                           12.9        EU
# 99                           11.4        EU
# 105                           6.6        EU
# 111                           0.0        EU
# 113                           4.9        EU
# 120                           9.4        EU
# 126                           6.7        EU
# 135                          10.9        EU
# 136                          11.0        EU
# 139                           6.3        EU
# 140                          10.4        EU
# 147                           0.0        EU
# 151                           9.6        EU
# 155                          11.4        EU
# 156                          10.6        EU
# 160                          10.0        EU
# 165                           7.2        EU
# 166                          10.2        EU
# 170                           3.9        EU
# 180                           8.9        EU
# 182                          10.4        EU

# %%
# Filter DataFrame to only include European countries with wine_servings > 300.
drinks[(drinks["continent"]== 'EU') & (drinks["wine_servings"] > 300)]
# Out:
#       country  beer_servings  spirit_servings  wine_servings  \
# 3     Andorra            245              138            312
# 61     France            127              151            370
# 136  Portugal            194               67            339
#
#      total_litres_of_pure_alcohol continent
# 3                            12.4        EU
# 61                           11.8        EU
# 136                          11.0        EU

# %%
# Calculate the average beer_servings for all of Europe.
drinks[drinks["continent"]== 'EU']["beer_servings"].mean()
# Out:
# 193.77777777777777

# %%
# Determine which 10 countries have the highest total_litres_of_pure_alcohol.
drinks.sort_values('total_litres_of_pure_alcohol', ascending=False).head(10)
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 15              Belarus            142              373             42
# 98            Lithuania            343              244             56
# 3               Andorra            245              138            312
# 68              Grenada            199              438             28
# 45       Czech Republic            361              170            134
# 61               France            127              151            370
# 141  Russian Federation            247              326             73
# 81              Ireland            313              118            165
# 155            Slovakia            196              293            116
# 99           Luxembourg            236              133            271
#
#      total_litres_of_pure_alcohol continent
# 15                           14.4        EU
# 98                           12.9        EU
# 3                            12.4        EU
# 68                           11.9       NaN
# 45                           11.8        EU
# 61                           11.8        EU
# 141                          11.5        AS
# 81                           11.4        EU
# 155                          11.4        EU
# 99                           11.4        EU

# %% [markdown]
# <a id="columns"></a>
# ### Renaming, Adding, and Removing Columns
#
# - **Objective:** Manipulate `DataFrame` columns.

# %%
# Rename one or more columns in a single output using value mapping.
drinks.rename(columns={'beer_servings':'beer', 'wine_servings':'wine'})
# Out:
#                   country  beer  spirit_servings  wine  \
# 0             Afghanistan     0                0     0
# 1                 Albania    89              132    54
# 2                 Algeria    25                0    14
# 3                 Andorra   245              138   312
# 4                  Angola   217               57    45
# 5       Antigua & Barbuda   102              128    45
# 6               Argentina   193               25   221
# 7                 Armenia    21              179    11
# 8               Australia   261               72   212
# 9                 Austria   279               75   191
# 10             Azerbaijan    21               46     5
# 11                Bahamas   122              176    51
# 12                Bahrain    42               63     7
# 13             Bangladesh     0                0     0
# 14               Barbados   143              173    36
# 15                Belarus   142              373    42
# 16                Belgium   295               84   212
# 17                 Belize   263              114     8
# 18                  Benin    34                4    13
# 19                 Bhutan    23                0     0
# 20                Bolivia   167               41     8
# 21     Bosnia-Herzegovina    76              173     8
# 22               Botswana   173               35    35
# 23                 Brazil   245              145    16
# 24                 Brunei    31                2     1
# 25               Bulgaria   231              252    94
# 26           Burkina Faso    25                7     7
# 27                Burundi    88                0     0
# 28          Cote d'Ivoire    37                1     7
# 29             Cabo Verde   144               56    16
# ..                    ...   ...              ...   ...
# 163              Suriname   128              178     7
# 164             Swaziland    90                2     2
# 165                Sweden   152               60   186
# 166           Switzerland   185              100   280
# 167                 Syria     5               35    16
# 168            Tajikistan     2               15     0
# 169              Thailand    99              258     1
# 170             Macedonia   106               27    86
# 171           Timor-Leste     1                1     4
# 172                  Togo    36                2    19
# 173                 Tonga    36               21     5
# 174     Trinidad & Tobago   197              156     7
# 175               Tunisia    51                3    20
# 176                Turkey    51               22     7
# 177          Turkmenistan    19               71    32
# 178                Tuvalu     6               41     9
# 179                Uganda    45                9     0
# 180               Ukraine   206              237    45
# 181  United Arab Emirates    16              135     5
# 182        United Kingdom   219              126   195
# 183              Tanzania    36                6     1
# 184                   USA   249              158    84
# 185               Uruguay   115               35   220
# 186            Uzbekistan    25              101     8
# 187               Vanuatu    21               18    11
# 188             Venezuela   333              100     3
# 189               Vietnam   111                2     1
# 190                 Yemen     6                0     0
# 191                Zambia    32               19     4
# 192              Zimbabwe    64               18     4
#
#      total_litres_of_pure_alcohol continent
# 0                             0.0        AS
# 1                             4.9        EU
# 2                             0.7        AF
# 3                            12.4        EU
# 4                             5.9        AF
# 5                             4.9       NaN
# 6                             8.3        SA
# 7                             3.8        EU
# 8                            10.4        OC
# 9                             9.7        EU
# 10                            1.3        EU
# 11                            6.3       NaN
# 12                            2.0        AS
# 13                            0.0        AS
# 14                            6.3       NaN
# 15                           14.4        EU
# 16                           10.5        EU
# 17                            6.8       NaN
# 18                            1.1        AF
# 19                            0.4        AS
# 20                            3.8        SA
# 21                            4.6        EU
# 22                            5.4        AF
# 23                            7.2        SA
# 24                            0.6        AS
# 25                           10.3        EU
# 26                            4.3        AF
# 27                            6.3        AF
# 28                            4.0        AF
# 29                            4.0        AF
# ..                            ...       ...
# 163                           5.6        SA
# 164                           4.7        AF
# 165                           7.2        EU
# 166                          10.2        EU
# 167                           1.0        AS
# 168                           0.3        AS
# 169                           6.4        AS
# 170                           3.9        EU
# 171                           0.1        AS
# 172                           1.3        AF
# 173                           1.1        OC
# 174                           6.4       NaN
# 175                           1.3        AF
# 176                           1.4        AS
# 177                           2.2        AS
# 178                           1.0        OC
# 179                           8.3        AF
# 180                           8.9        EU
# 181                           2.8        AS
# 182                          10.4        EU
# 183                           5.7        AF
# 184                           8.7       NaN
# 185                           6.6        SA
# 186                           2.4        AS
# 187                           0.9        OC
# 188                           7.7        SA
# 189                           2.0        AS
# 190                           0.1        AS
# 191                           2.5        AF
# 192                           4.7        AF
#
# [193 rows x 6 columns]

# %% [markdown]
# Where are my new columns???

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# Rename one or more columns in the original DataFrame.
drinks.rename(columns={'beer_servings':'beer', 'wine_servings':'wine'}, inplace=True)

drinks.head()
# Out:
#        country  beer  spirit_servings  wine  total_litres_of_pure_alcohol  \
# 0  Afghanistan     0                0     0                           0.0
# 1      Albania    89              132    54                           4.9
# 2      Algeria    25                0    14                           0.7
# 3      Andorra   245              138   312                          12.4
# 4       Angola   217               57    45                           5.9
#
#   continent
# 0        AS
# 1        EU
# 2        AF
# 3        EU
# 4        AF

# %% [markdown]
# or you could have re-assigned the new dataframe to the same variable:
#
# ```python
# drinks = drinks.rename(columns={'beer_servings':'beer', 'wine_servings':'wine'})
# ```

# %%
# Replace all column names using a list of matching length
drink_cols = ['country', 'beer', 'spirit', 'wine', 'litres', 'continent'] 

# Replace during file reading (disables the header from the file)
drinks_renamed = pd.read_csv('data/drinks.csv', header=0, names=drink_cols)
drinks_renamed.head()
# Out:
#        country  beer  spirit  wine  litres continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %%
# Replace after file has already been read into Python.
drinks.columns = drink_cols

drinks.head()
# Out:
#        country  beer  spirit  wine  litres continent
# 0  Afghanistan     0       0     0     0.0        AS
# 1      Albania    89     132    54     4.9        EU
# 2      Algeria    25       0    14     0.7        AF
# 3      Andorra   245     138   312    12.4        EU
# 4       Angola   217      57    45     5.9        AF

# %% [markdown]
# **Easy Column Operations**<br>
# Rather than having to reference indexes and create for loops to do column-wise operations, Pandas is smart and knows that when we add columns together we want to add the values in each row together.

# %%
# Add a new column as a function of existing columns.
drinks['servings'] = drinks["beer"] + drinks["spirit"] + drinks["wine"]
drinks['mL'] = drinks["litres"] * 1000

drinks.head()
# Out:
#        country  beer  spirit  wine  litres continent  servings       mL
# 0  Afghanistan     0       0     0     0.0        AS         0      0.0
# 1      Albania    89     132    54     4.9        EU       275   4900.0
# 2      Algeria    25       0    14     0.7        AF        39    700.0
# 3      Andorra   245     138   312    12.4        EU       695  12400.0
# 4       Angola   217      57    45     5.9        AF       319   5900.0

# %% [markdown]
# **Removing Columns**

# %%
# axis=0 for rows, 1 for columns
drinks.drop('mL', axis=1)
# Out:
#                   country  beer  spirit  wine  litres continent  servings
# 0             Afghanistan     0       0     0     0.0        AS         0
# 1                 Albania    89     132    54     4.9        EU       275
# 2                 Algeria    25       0    14     0.7        AF        39
# 3                 Andorra   245     138   312    12.4        EU       695
# 4                  Angola   217      57    45     5.9        AF       319
# 5       Antigua & Barbuda   102     128    45     4.9       NaN       275
# 6               Argentina   193      25   221     8.3        SA       439
# 7                 Armenia    21     179    11     3.8        EU       211
# 8               Australia   261      72   212    10.4        OC       545
# 9                 Austria   279      75   191     9.7        EU       545
# 10             Azerbaijan    21      46     5     1.3        EU        72
# 11                Bahamas   122     176    51     6.3       NaN       349
# 12                Bahrain    42      63     7     2.0        AS       112
# 13             Bangladesh     0       0     0     0.0        AS         0
# 14               Barbados   143     173    36     6.3       NaN       352
# 15                Belarus   142     373    42    14.4        EU       557
# 16                Belgium   295      84   212    10.5        EU       591
# 17                 Belize   263     114     8     6.8       NaN       385
# 18                  Benin    34       4    13     1.1        AF        51
# 19                 Bhutan    23       0     0     0.4        AS        23
# 20                Bolivia   167      41     8     3.8        SA       216
# 21     Bosnia-Herzegovina    76     173     8     4.6        EU       257
# 22               Botswana   173      35    35     5.4        AF       243
# 23                 Brazil   245     145    16     7.2        SA       406
# 24                 Brunei    31       2     1     0.6        AS        34
# 25               Bulgaria   231     252    94    10.3        EU       577
# 26           Burkina Faso    25       7     7     4.3        AF        39
# 27                Burundi    88       0     0     6.3        AF        88
# 28          Cote d'Ivoire    37       1     7     4.0        AF        45
# 29             Cabo Verde   144      56    16     4.0        AF       216
# ..                    ...   ...     ...   ...     ...       ...       ...
# 163              Suriname   128     178     7     5.6        SA       313
# 164             Swaziland    90       2     2     4.7        AF        94
# 165                Sweden   152      60   186     7.2        EU       398
# 166           Switzerland   185     100   280    10.2        EU       565
# 167                 Syria     5      35    16     1.0        AS        56
# 168            Tajikistan     2      15     0     0.3        AS        17
# 169              Thailand    99     258     1     6.4        AS       358
# 170             Macedonia   106      27    86     3.9        EU       219
# 171           Timor-Leste     1       1     4     0.1        AS         6
# 172                  Togo    36       2    19     1.3        AF        57
# 173                 Tonga    36      21     5     1.1        OC        62
# 174     Trinidad & Tobago   197     156     7     6.4       NaN       360
# 175               Tunisia    51       3    20     1.3        AF        74
# 176                Turkey    51      22     7     1.4        AS        80
# 177          Turkmenistan    19      71    32     2.2        AS       122
# 178                Tuvalu     6      41     9     1.0        OC        56
# 179                Uganda    45       9     0     8.3        AF        54
# 180               Ukraine   206     237    45     8.9        EU       488
# 181  United Arab Emirates    16     135     5     2.8        AS       156
# 182        United Kingdom   219     126   195    10.4        EU       540
# 183              Tanzania    36       6     1     5.7        AF        43
# 184                   USA   249     158    84     8.7       NaN       491
# 185               Uruguay   115      35   220     6.6        SA       370
# 186            Uzbekistan    25     101     8     2.4        AS       134
# 187               Vanuatu    21      18    11     0.9        OC        50
# 188             Venezuela   333     100     3     7.7        SA       436
# 189               Vietnam   111       2     1     2.0        AS       114
# 190                 Yemen     6       0     0     0.1        AS         6
# 191                Zambia    32      19     4     2.5        AF        55
# 192              Zimbabwe    64      18     4     4.7        AF        86
#
# [193 rows x 7 columns]

# %%
drinks.head()
# Out:
#        country  beer  spirit  wine  litres continent  servings       mL
# 0  Afghanistan     0       0     0     0.0        AS         0      0.0
# 1      Albania    89     132    54     4.9        EU       275   4900.0
# 2      Algeria    25       0    14     0.7        AF        39    700.0
# 3      Andorra   245     138   312    12.4        EU       695  12400.0
# 4       Angola   217      57    45     5.9        AF       319   5900.0

# %%
# Drop on the original DataFrame rather than returning a new one.
drinks.drop('mL', axis=1, inplace=True)

drinks.head()
# Out:
#        country  beer  spirit  wine  litres continent  servings
# 0  Afghanistan     0       0     0     0.0        AS         0
# 1      Albania    89     132    54     4.9        EU       275
# 2      Algeria    25       0    14     0.7        AF        39
# 3      Andorra   245     138   312    12.4        EU       695
# 4       Angola   217      57    45     5.9        AF       319

# %%
# Drop multiple columns.
drinks.drop(['beer', 'servings'], axis=1)
# Out:
#                   country  spirit  wine  litres continent
# 0             Afghanistan       0     0     0.0        AS
# 1                 Albania     132    54     4.9        EU
# 2                 Algeria       0    14     0.7        AF
# 3                 Andorra     138   312    12.4        EU
# 4                  Angola      57    45     5.9        AF
# 5       Antigua & Barbuda     128    45     4.9       NaN
# 6               Argentina      25   221     8.3        SA
# 7                 Armenia     179    11     3.8        EU
# 8               Australia      72   212    10.4        OC
# 9                 Austria      75   191     9.7        EU
# 10             Azerbaijan      46     5     1.3        EU
# 11                Bahamas     176    51     6.3       NaN
# 12                Bahrain      63     7     2.0        AS
# 13             Bangladesh       0     0     0.0        AS
# 14               Barbados     173    36     6.3       NaN
# 15                Belarus     373    42    14.4        EU
# 16                Belgium      84   212    10.5        EU
# 17                 Belize     114     8     6.8       NaN
# 18                  Benin       4    13     1.1        AF
# 19                 Bhutan       0     0     0.4        AS
# 20                Bolivia      41     8     3.8        SA
# 21     Bosnia-Herzegovina     173     8     4.6        EU
# 22               Botswana      35    35     5.4        AF
# 23                 Brazil     145    16     7.2        SA
# 24                 Brunei       2     1     0.6        AS
# 25               Bulgaria     252    94    10.3        EU
# 26           Burkina Faso       7     7     4.3        AF
# 27                Burundi       0     0     6.3        AF
# 28          Cote d'Ivoire       1     7     4.0        AF
# 29             Cabo Verde      56    16     4.0        AF
# ..                    ...     ...   ...     ...       ...
# 163              Suriname     178     7     5.6        SA
# 164             Swaziland       2     2     4.7        AF
# 165                Sweden      60   186     7.2        EU
# 166           Switzerland     100   280    10.2        EU
# 167                 Syria      35    16     1.0        AS
# 168            Tajikistan      15     0     0.3        AS
# 169              Thailand     258     1     6.4        AS
# 170             Macedonia      27    86     3.9        EU
# 171           Timor-Leste       1     4     0.1        AS
# 172                  Togo       2    19     1.3        AF
# 173                 Tonga      21     5     1.1        OC
# 174     Trinidad & Tobago     156     7     6.4       NaN
# 175               Tunisia       3    20     1.3        AF
# 176                Turkey      22     7     1.4        AS
# 177          Turkmenistan      71    32     2.2        AS
# 178                Tuvalu      41     9     1.0        OC
# 179                Uganda       9     0     8.3        AF
# 180               Ukraine     237    45     8.9        EU
# 181  United Arab Emirates     135     5     2.8        AS
# 182        United Kingdom     126   195    10.4        EU
# 183              Tanzania       6     1     5.7        AF
# 184                   USA     158    84     8.7       NaN
# 185               Uruguay      35   220     6.6        SA
# 186            Uzbekistan     101     8     2.4        AS
# 187               Vanuatu      18    11     0.9        OC
# 188             Venezuela     100     3     7.7        SA
# 189               Vietnam       2     1     2.0        AS
# 190                 Yemen       0     0     0.1        AS
# 191                Zambia      19     4     2.5        AF
# 192              Zimbabwe      18     4     4.7        AF
#
# [193 rows x 5 columns]
